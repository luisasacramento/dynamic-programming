# %%
import pandas as pd

# %%
# CSV extraido do Dbeaver

dados = pd.read_csv('C:/Users/labsfiap/Desktop/_SELECT_album_Title_album_AlbumId_Artist_Name_Artist_ArtistId_Fr_202408202014.csv')

dados
# Out:
#                                                  Title  AlbumId  \
# 0                For Those About To Rock We Salute You        1
# 1                                    Balls to the Wall        2
# 2                                    Restless and Wild        3
# 3                                    Let There Be Rock        4
# 4                                             Big Ones        5
# ..                                                 ...      ...
# 342                             Respighi:Pines of Rome      343
# 343  Schubert: The Late String Quartets & String Qu...      344
# 344                                Monteverdi: L'Orfeo      345
# 345                              Mozart: Chamber Music      346
# 346  Koyaanisqatsi (Soundtrack from the Motion Pict...      347
#
#                                                   Name  ArtistId
# 0                                                AC/DC         1
# 1                                               Accept         2
# ...

# %%
'''
1. Selecione as colunas AlbumId, Title e ArtistId da tabela Album e exporte o arquivo em csv.
2. Junte os dados da tabela chamada Album com a tabela chamada Track em SQL.
3. Junte os dados da tabela chamada Album com a tabela chamada Track em Python e faça um merge pela coluna AlbumId

'''

# %%
'''
4. Duração Total do Álbum - Escreva uma função que calcule a duração total em
milissegundos de cada álbum.
5. Álbum Mais Longo - Crie uma função que identifique o álbum com a maior
duração total. Utilize programação dinâmica para armazenar as durações dos
álbuns.
6. Contagem de Faixas por Álbum - Crie uma função que conte quantas faixas
existem em cada álbum. Armazene resultados intermediários usando um
dicionário

'''
